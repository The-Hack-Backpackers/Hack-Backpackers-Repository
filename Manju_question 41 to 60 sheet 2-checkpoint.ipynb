# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('HospitalDatabase-Discharges.csv')
df
# Out:
#      AdmissionID  PatientID AdmissionDate DischargeDate DischargeDisposition  \
# 0              1          9      1/1/2018      1/7/2018              Expired
# 1            257         93      1/6/2018     1/18/2018              Expired
# 2            152        101      1/7/2018     1/11/2018              Expired
# 3            361        102      1/7/2018     1/15/2018              Expired
# 4            258        103      1/7/2018     1/15/2018              Expired
# ..           ...        ...           ...           ...                  ...
# 715          715        716     2/21/2018      3/6/2018             Transfer
# 716          698        723     2/22/2018     2/26/2018             Transfer
# 717          704        724     2/22/2018     2/27/2018             Transfer
# 718          716        733     2/22/2018      3/5/2018             Transfer
# 719          710        742     2/22/2018     3/10/2018             Transfer
#
#               Service PrimaryDiagnosis  ExpectedLOS  ExpectedMortality
# 0          Cardiology              AMI     9.646857           0.061540
# 1          Cardiology       Broken Leg     6.816558           0.628827
# 2          Cardiology   Kidney Failure     6.580273           0.573887
# 3          Cardiology             Afib    12.794536           0.222163
# 4          Cardiology       Broken Leg     2.639297           0.055468
# ..                ...              ...          ...                ...
# 715               ICU    Heart Failure    11.362095           0.370695
# 716               ICU    Heart Failure    10.262312           0.812930
# 717  General Medicine        Pneumonia     6.036234           0.094128
# 718               ICU    Heart Failure    13.323413           0.490892
# 719  General Medicine         Diabetes     7.195441           0.286439
#
# [720 rows x 9 columns]

# %%
# 45 Calculate mortality by diagnosis.

# %%
df.groupby(['PrimaryDiagnosis']).count()['ExpectedMortality']
# Out:
# PrimaryDiagnosis
# AMI                    48
# Afib                   11
# Broken Leg              9
# Diabetes               64
# Fever                  19
# Flu                    80
# Heart Failure          78
# Hip Fracture           23
# Hypertension           50
# Kidney Failure         20
# Knee Replacement       23
# Laceration             29
# Migraine               12
# Pain                    7
# Pneumonia             177
# Spinal Cord Injury      2
# Stroke                 68
# Name: ExpectedMortality, dtype: int64

# %%
df.groupby(['PrimaryDiagnosis']).count()['ExpectedMortality'].plot(kind='bar',figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='PrimaryDiagnosis'>

# %%
df=pd.read_csv('HospitalDatabase-Providers.csv')
df
# Out:
#     ProviderID     ProviderName ProviderSpecialty ProviderDateOnStaff
# 0            1        Sally Sue        Pediatrics            1/1/1993
# 1            2       Mike Myers        Pediatrics            5/2/1993
# 2            3   Jordan Michael        Pediatrics           6/24/1993
# 3            4        Ted Texas        Pediatrics          12/23/1993
# 4            5         Ala Bama        Pediatrics           1/10/1995
# 5            6       Harry Kane        Pediatrics           7/21/1995
# 6            7        Barry Bar        Pediatrics          11/21/1995
# 7            8        Ted Green        Pediatrics           5/30/1996
# 8            9        Ted Black        Pediatrics           2/20/1997
# 9           10         Fred Man           Surgery           3/17/1998
# 10          11     Kim Kimberly           Surgery           5/10/1998
# 11          12         Sarah Ab           Surgery           8/18/1998
# 12          13  Abigail Marriot           Surgery           11/8/1998
# 13          14          Dave Yu           Surgery           6/26/1999
# 14          15  Christian Saint           Surgery           8/27/2000
# 15          16     Perry Pardon           Surgery           2/13/2001
# 16          17     Kent Kendall        Cardiology          12/22/2001
# 17          18       Ryan Kevin        Cardiology           1/14/2003
# 18          19     Tyler Conner        Cardiology            7/9/2003
# 19          20    Bailey Barret        Cardiology           8/20/2003
# 20          21      Megan Bonco        Cardiology           2/17/2004
# 21          22    Joesph Walter        Cardiology            2/4/2005
# 22          23      Walter King        Cardiology           3/12/2006
# 23          24        Luke Long        Cardiology           4/28/2006
# 24          25      Justin Time       PrimaryCare           6/21/2006
# 25          26      Mike Joseph       PrimaryCare          12/29/2006
# 26          27   Bridget Brenda       PrimaryCare           6/30/2007
# 27          28      Brenda Bing       PrimaryCare          11/18/2007
# 28          29    Chandler Bing       PrimaryCare           12/7/2007
# 29          30      Joesph Ross       PrimaryCare           11/8/2008
# 30          31     Dwight Scott       PrimaryCare           4/18/2009
# 31          32  Michael Halpert       PrimaryCare            9/2/2009
# 32          33      Pamela Ding       PrimaryCare          11/12/2009
# 33          34       Tony Creed       PrimaryCare           4/28/2010
# 34          35  Phyllis Stanley       PrimaryCare            5/5/2011
# 35          36        Holly Hue       PrimaryCare           6/24/2012
# 36          37        Trent Tye       PrimaryCare           1/12/2013
# 37          38    Kimberly Cone       PrimaryCare           5/23/2013
# 38          39       Harry West       PrimaryCare           7/14/2013
# 39          40     Rosie Renter       PrimaryCare           9/11/2013

# %%
# 59Create a dataframe by splitting provider name to firstname and lastname with names for the columns.
seprated=df['ProviderName'].str.split(expand=True)
seprated
# Out:
#             0         1
# 0       Sally       Sue
# 1        Mike     Myers
# 2      Jordan   Michael
# 3         Ted     Texas
# 4         Ala      Bama
# 5       Harry      Kane
# 6       Barry       Bar
# 7         Ted     Green
# 8         Ted     Black
# 9        Fred       Man
# 10        Kim  Kimberly
# 11      Sarah        Ab
# 12    Abigail   Marriot
# 13       Dave        Yu
# 14  Christian     Saint
# 15      Perry    Pardon
# 16       Kent   Kendall
# 17       Ryan     Kevin
# 18      Tyler    Conner
# 19     Bailey    Barret
# 20      Megan     Bonco
# 21     Joesph    Walter
# 22     Walter      King
# 23       Luke      Long
# 24     Justin      Time
# 25       Mike    Joseph
# 26    Bridget    Brenda
# 27     Brenda      Bing
# 28   Chandler      Bing
# 29     Joesph      Ross
# 30     Dwight     Scott
# 31    Michael   Halpert
# 32     Pamela      Ding
# 33       Tony     Creed
# 34    Phyllis   Stanley
# 35      Holly       Hue
# 36      Trent       Tye
# 37   Kimberly      Cone
# 38      Harry      West
# 39      Rosie    Renter

# %%
import pandas as pd
df=pd.read_csv('HospitalDatabase-AmulateryVisit.csv')
df
# Out:
#      VisitID  PatientMRN  ProviderID DateofVisit DateScheduled  \
# 0        202         840          29   3/19/2019     3/13/2019
# 1        436         820          25   3/19/2019     2/24/2019
# 2        794         879          30    4/2/2019     3/19/2019
# 3        799         884          37    3/3/2019     2/25/2019
# 4        515          32          26   3/16/2019     2/20/2019
# ..       ...         ...         ...         ...           ...
# 945      788         873           1   3/27/2019     3/10/2019
# 946      703         855          36   3/12/2019     2/19/2019
# 947      481         865          13    5/3/2019     4/25/2019
# 948      398         635          10    2/9/2019      2/8/2019
# 949      695         847          24    3/4/2019      2/5/2019
#
#      VisitDepartmentID     VisitType  BloodPressureSystolic  \
# 0                   10      Physical                  188.0
# 1                    3     Follow Up                  179.0
# 2                   11  Telemedicine                  133.0
# 3                    4  Telemedicine                  132.0
# 4                   11  Telemedicine                  131.0
# ..                 ...           ...                    ...
# 945                  5  Telemedicine                  187.0
# 946                 10     Follow Up                  182.0
# 947                 12           New                  150.0
# 948                  1      Physical                  177.0
# 949                 12     Follow Up                  165.0
#
#      BloodPressureDiastolic      Pulse VisitStatus
# 0                144.143427  83.044920     No Show
# 1                118.876808  90.309544     No Show
# 2                 98.749563  80.859776     No Show
# 3                 98.001270  82.184737     No Show
# 4                 85.115632  89.192362     No Show
# ..                      ...        ...         ...
# 945              126.695141  70.049167    Canceled
# 946              140.703502  73.380812    Canceled
# 947               84.841197  61.625454    Canceled
# 948              125.037534  53.287036    Canceled
# 949              116.879318  56.180317    Canceled
#
# [950 rows x 11 columns]

# %%
#56Count of canceled status.
df['VisitStatus'].value_counts()
# Out:
# Completed    736
# No Show      154
# Canceled      60
# Name: VisitStatus, dtype: int64

# %%
#52Retrieve the row with minimum DBP using sorting technique.
import pandas as pd
df=pd.read_csv('HospitalDatabase-AmulateryVisit.csv')
df['BloodPressureDiastolic'].sort_values()
# Out:
# 757    51.695653
# 456    54.099878
# 118    54.285242
# 231    56.594973
# 545    57.043944
#          ...
# 805          NaN
# 807          NaN
# 808          NaN
# 810          NaN
# 813          NaN
# Name: BloodPressureDiastolic, Length: 950, dtype: float64

# %%
df['BloodPressureDiastolic'].min(axis=0)
# Out:
# 51.6956525

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('HospitalDatabase-EDVisits.csv')
df
# Out:
#       EDVisitID  PatientID    VisitDate EDDischargeTime  Acuity  \
# 0             1          1  12:00:00 AM     11:20:23 AM       1
# 1            12         12   2:45:40 AM      2:00:01 AM       2
# 2            13         13   3:09:25 AM      5:00:21 AM       3
# 3            14         14   3:12:19 AM      4:32:29 AM       3
# 4            15         15   3:46:33 AM      6:24:53 AM       3
# ...         ...        ...          ...             ...     ...
# 1194       1183        929  10:38:43 AM      2:31:52 AM       4
# 1195       1186        932  11:52:38 AM     10:19:42 AM       1
# 1196       1187        933  12:11:12 PM      4:41:15 PM       1
# 1197       1188        934  12:21:46 PM      6:32:21 PM       1
# 1198       1189        935  12:51:15 PM     11:40:41 PM       1
#
#      ReasonForVisit EDDisposition
# 0      Stomach Ache      Admitted
# 1          Migraine      Admitted
# 2      Stomach Ache      Admitted
# 3          Migraine      Admitted
# 4        Chest Pain      Admitted
# ...             ...           ...
# 1194     Chest Pain    Discharged
# 1195      Pneumonia    Discharged
# 1196      Pneumonia    Discharged
# 1197      Pneumonia    Discharged
# 1198      Pneumonia    Discharged
#
# [1199 rows x 7 columns]

# %%
#53 Take the ReasonForVisit from user, find the number of patients admitted with that ReasonForVisit.
df.groupby('ReasonForVisit')['EDDisposition'].apply(lambda x: (x=='Admitted').sum()).reset_index(name='count')
# Out:
#          ReasonForVisit  count
# 0              Accident     39
# 1              Bleeding     16
# 2          Car Accident     17
# 3            Chest Pain     94
# 4                 Cough      0
# 5                 Fever     46
# 6              Gun Shot     16
# 7          Intoxication      0
# 8            Laceration      0
# 9              Migraine     47
# 10            Pneumonia    136
# 11  Shortness of Breath     72
# 12         Stomach Ache     32

# %%
#58 Display total count of patients service wise based on gender.
df=pd.read_csv('HospitalDatabase-ReAdmissionRegistry.csv')
df['Service'].value_counts()
# Out:
# General Medicine    263
# ICU                 151
# Hospitalist         101
# Cardiology           95
# Neurology            65
# Orthopeadics         45
# Name: Service, dtype: int64

# %%
df=pd.read_csv('HospitalDatabase-Pateint.csv')
df['Gender'].value_counts()
# Out:
# Male      537
# Female    408
# Name: Gender, dtype: int64

# %%
sns.FacetGrid(strokes_data, hue="stroke", height = 8).map(sns.distplot, "age").add_legend()
plt.title("Distplot for patients' age")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [92], in <cell line: 1>()
# ----> 1 sns.FacetGrid(strokes_data, hue="stroke", height = 8).map(sns.distplot, "age").add_legend()
#       2 plt.title("Distplot for patients' age")
#       3 plt.show()
#
# NameError: name 'strokes_data' is not defined
