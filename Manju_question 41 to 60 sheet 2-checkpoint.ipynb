# %% [markdown]
# # 45 Calculate mortality by diagnosis.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('HospitalDatabase-Discharges.csv')
pd.pivot_table(df,index=['PrimaryDiagnosis','ExpectedMortality'])
# Out:
#                                     AdmissionID  ExpectedLOS  PatientID
# PrimaryDiagnosis ExpectedMortality
# AMI              0.004666                   181     9.852817        459
#                  0.009274                   511    12.859779        636
#                  0.010823                   451    11.214127        173
#                  0.012913                    86    12.040957        427
#                  0.017010                   191    11.112877        580
# ...                                         ...          ...        ...
# Stroke           0.926305                    12    14.457094        159
#                  0.957984                    27    10.516934        335
#                  0.958035                   444    16.838918         95
#                  0.980479                   207    13.156892        123
#                  0.980886                   203    10.621573         85
#
# [720 rows x 3 columns]

# %%
df.groupby(['PrimaryDiagnosis']).count()['ExpectedMortality'].plot(kind='bar',figsize=(10,7))
# Out:
# <AxesSubplot:xlabel='PrimaryDiagnosis'>

# %% [markdown]
# # 59Create a dataframe by splitting provider name to firstname and lastname with names for the columns.

# %%
df=pd.read_csv('HospitalDatabase-Providers.csv')
seprated=df['ProviderName'].str.split(expand=True)
seprated
# Out:
#             0         1
# 0       Sally       Sue
# 1        Mike     Myers
# 2      Jordan   Michael
# 3         Ted     Texas
# 4         Ala      Bama
# 5       Harry      Kane
# 6       Barry       Bar
# 7         Ted     Green
# 8         Ted     Black
# 9        Fred       Man
# 10        Kim  Kimberly
# 11      Sarah        Ab
# 12    Abigail   Marriot
# 13       Dave        Yu
# 14  Christian     Saint
# 15      Perry    Pardon
# 16       Kent   Kendall
# 17       Ryan     Kevin
# 18      Tyler    Conner
# 19     Bailey    Barret
# 20      Megan     Bonco
# 21     Joesph    Walter
# 22     Walter      King
# 23       Luke      Long
# 24     Justin      Time
# 25       Mike    Joseph
# 26    Bridget    Brenda
# 27     Brenda      Bing
# 28   Chandler      Bing
# 29     Joesph      Ross
# 30     Dwight     Scott
# 31    Michael   Halpert
# 32     Pamela      Ding
# 33       Tony     Creed
# 34    Phyllis   Stanley
# 35      Holly       Hue
# 36      Trent       Tye
# ...

# %% [markdown]
# # 56Count of canceled status.

# %%
import pandas as pd
df=pd.read_csv('HospitalDatabase-AmulateryVisit.csv')
df['VisitStatus'].value_counts()
# Out:
# Completed    736
# No Show      154
# Canceled      60
# Name: VisitStatus, dtype: int64

# %% [markdown]
# # 52Retrieve the row with minimum DBP using sorting technique.

# %%
import pandas as pd
df=pd.read_csv('HospitalDatabase-AmulateryVisit.csv')
df['BloodPressureDiastolic'].sort_values()
# Out:
# 757    51.695653
# 456    54.099878
# 118    54.285242
# 231    56.594973
# 545    57.043944
#          ...
# 805          NaN
# 807          NaN
# 808          NaN
# 810          NaN
# 813          NaN
# Name: BloodPressureDiastolic, Length: 950, dtype: float64

# %%
df['BloodPressureDiastolic'].min(axis=0)
# Out:
# 51.6956525

# %% [markdown]
# # 58 Display total count of patients service wise based on gender.

# %%
# Swati Did this one

# %% [markdown]
# # 48 Display the average LOS based on Service and Discharge Disposition(Maintain the column Hierarchy).

# %%
import pandas as pd
df=pd.read_csv('HospitalDatabase-ReAdmissionRegistry.csv')
pd.pivot_table(df,index=['Service','DischargeDisposition'],values='ExpectedLOS',aggfunc='mean',margins=True)
# Out:
#                                        ExpectedLOS
# Service          DischargeDisposition
# Cardiology       Expired                  9.202626
#                  Home                    12.864936
#                  Transfer                11.818403
# General Medicine Expired                  5.874003
#                  Home                     6.105696
#                  Transfer                 6.116124
# Hospitalist      Expired                  6.775636
#                  Home                     8.009046
#                  Transfer                 5.701389
# ICU              Expired                  9.919063
#                  Home                    13.451158
#                  Transfer                11.989238
# Neurology        Expired                  9.384312
#                  Home                    12.538859
#                  Transfer                11.469198
# Orthopeadics     Expired                  3.943883
#                  Home                     3.508337
# ...

# %%
df['ExpectedLOS'].mean()
# Out:
# 8.8245891590875

# %% [markdown]
# # 53 Take the ReasonForVisit from user, find the number of patients admitted with that ReasonForVisit.

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('HospitalDatabase-EDVisits.csv')
user=input('Reason for visit')
# Out:
# Reason for visit:- Accident

# %%
print(df['ReasonForVisit'].value_counts()['Accident'])
# Out:
# 39

# %% [markdown]
# # Answer:- ReasonForVisit from user is Accident and number of patients admitted with that ReasonForVisit are 39.

# %% [markdown]
# # 60 Find the list of patients whose ExpectedLOS is greater than the value given by the user.

# %%
df=pd.read_csv('HospitalDatabase-ReAdmissionRegistry.csv')
df
# Out:
#      AdmissionID  PatientID AdmissionDate DischargeDate DischargeDisposition  \
# 0            389          1      1/1/2018      1/4/2018                 Home
# 1            635          2      1/1/2018      1/4/2018                 Home
# 2            606          3      1/1/2018      1/4/2018                 Home
# 3            587          5      1/1/2018      1/5/2018                 Home
# 4            640          6      1/1/2018      1/5/2018                 Home
# ..           ...        ...           ...           ...                  ...
# 715          521        738     2/22/2018      3/7/2018                 Home
# 716          548        739     2/22/2018      3/8/2018                 Home
# 717          509        740     2/22/2018      3/8/2018                 Home
# 718          605        741     2/22/2018     3/10/2018                 Home
# 719          710        742     2/22/2018     3/10/2018             Transfer
#
# ...

# %%
user=input('Enter the ExpectedLOS :')
# Out:
# Enter the ExpectedLOS :16.472257

# %%
f_user = float(user)
df = df.loc[(df['ExpectedLOS'] > f_user)]
df
# Out:
#      AdmissionID  PatientID AdmissionDate DischargeDate DischargeDisposition  \
# 100          444         95      1/6/2018     1/19/2018                 Home
# 217           70        215     1/17/2018     1/26/2018                 Home
# 344          173        338     1/28/2018     1/31/2018                 Home
# 357          383        351     1/29/2018      2/1/2018                 Home
# 358          174        352     1/29/2018      2/2/2018              Expired
# 421          623        438      2/3/2018     2/15/2018                 Home
# 473           39        490      2/8/2018     2/22/2018                 Home
# 479          535        496      2/9/2018     2/12/2018                 Home
# 542          295        560     2/13/2018     2/26/2018              Expired
# 632          488        652     2/19/2018     2/22/2018                 Home
# 643          248        663     2/19/2018     2/28/2018                 Home
#
# ...
